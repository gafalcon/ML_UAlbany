# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data from file

# %%
data = []
with open('hw2.dat', 'r') as f:
    for l in f:
        data.append([ float(n) for n in l.split(' ') ])

# %%
data = np.array(data)
x = data[:,0]
y = data[:,1]

# %% [markdown]
# # Create polynomial X matrix

# %%
def create_poly_matrix(x, dimension):
    X = np.zeros( ((dimension+1), len(x)) )
    for i in range(0, dimension+1):
        X[i,:] = np.power(x,i)
    return X

# %% [markdown]
# # Calculate Regression

# %%
def regression(X, y):
    cor = X @ X.T
    lpm = np.linalg.inv(cor) @ X
    w = lpm @ y
    return w

# %% [markdown]
# # Calculate Predictions and Error

# %%
def predict(X, w, y):
    pred = X.T @ w
    err = y - pred
    total_err = err.sum()
    return pred, total_err

# %% [markdown]
# # Plot results

# %%
def plot_regression(x, y, pred, d):
    plt.plot(x,y, 'ro', x, pred, 'g^')
    plt.title("{}-degree polynomial regression".format(d))
    plt.xlabel("x")
    plt.ylabel("y")

# %% [markdown]
# # Polynomial d = 1

# %%
X = create_poly_matrix(x, 1)
w = regression(X, y)
pred, total_err = predict(X, w, y)
print("Total Error:",total_err)
plot_regression(x,y,pred,1)
# Out:
# Total Error: 3.728928277269006e-11

# %% [markdown]
# # Polynomial d = 3

# %%
X = create_poly_matrix(x, 3)
w = regression(X, y)
pred, total_err = predict(X, w, y)
print("Total Error:",total_err)
plot_regression(x,y,pred,3)
# Out:
# Total Error: 4.297362465877086e-11

# %% [markdown]
# # Polynomial d = 5

# %%
X = create_poly_matrix(x, 5)
w = regression(X, y)
pred, total_err = predict(X, w, y)
print("Total Error:",total_err)
plot_regression(x,y,pred,5)
# Out:
# Total Error: 1.6484591469634324e-11

# %% [markdown]
# # Polynomial d = 7

# %%
X = create_poly_matrix(x, 7)
w = regression(X, y)
pred, total_err = predict(X, w, y)
print("Total Error:",total_err)
plot_regression(x,y,pred,7)
# Out:
# Total Error: 1.1325482773827389e-09
